# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pyplot as plt

def st_err(datapts):
    return np.std(datapts, ddof=1)/np.sqrt(len(datapts))
def linear_model(x, m, c):
    return m*x + c

mu = 1.25663706212e-6
I = 3

a = open("dataset-7489f87f-84c7-4e38-9276-157ced702e8d.csv", "r")
b = open("dataset-184ccbbf-2c7b-44a4-993c-56e4da7a72e8.csv", "r")
c = open("dataset-523560fb-8cc6-44ed-841a-1020259900bc.csv", "r")
d = open("dataset-b70d457e-1db0-4d7a-8379-58dcc62c4fe6 (1).csv", "r")
e = open("dataset-a3580e3f-9172-4b3f-8766-0f2de6e9eac6.csv", "r")
f = open("dataset-effa3ef7-6f88-4d90-9831-3d4e16ad1e4a.csv", "r")
g = open("dataset-7ad14caa-2ceb-4287-a4f4-4728aa118209.csv", "r")
h = open("dataset-0968633c-4bc5-4c34-a8da-6b80a2bd61ac (1).csv", "r")
i = open("dataset-a3a9c2a6-ed21-41b7-a2cb-ed271907c7dd.csv", "r")
j = open("dataset-3af62e25-6d8d-4adf-923b-fe7ec537a578.csv", "r")
k = open("dataset-fdf07e9b-b2f3-400d-bed2-02bcaedf3d9d.csv", "r")

raw_data00 = np.loadtxt(a, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data03 = np.loadtxt(b, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data05 = np.loadtxt(c, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data08 = np.loadtxt(d, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data09 = np.loadtxt(e, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data12 = np.loadtxt(f, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data15 = np.loadtxt(g, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data18 = np.loadtxt(h, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data25 = np.loadtxt(i, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data30 = np.loadtxt(j, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)
raw_data40 = np.loadtxt(k, delimiter = ",", skiprows = 1, usecols=(0, 1, 2), unpack = True)

range_off00 = (raw_data00[0] >= 0) & (raw_data00[0] <= 6)
range_on00 = (raw_data00[0] >= 8) & (raw_data00[0] <= 14)
range_off03 = (raw_data03[0] >= 0) & (raw_data03[0] <= 6)
range_on03 = (raw_data03[0] >= 8) & (raw_data03[0] <= 14)
range_off05 = (raw_data05[0] >= 0) & (raw_data05[0] <= 6)
range_on05 = (raw_data05[0] >= 8) & (raw_data05[0] <= 14)
range_off08 = (raw_data08[0] >= 0) & (raw_data08[0] <= 6)
range_on08 = (raw_data08[0] >= 8) & (raw_data08[0] <= 14)
range_off09 = (raw_data09[0] >= 0) & (raw_data09[0] <= 6)
range_on09 = (raw_data09[0] >= 8) & (raw_data09[0] <= 14)
range_off12 = (raw_data12[0] >= 0) & (raw_data12[0] <= 6)
range_on12 = (raw_data12[0] >= 8) & (raw_data12[0] <= 14)
range_off15 = (raw_data15[0] >= 0) & (raw_data15[0] <= 6)
range_on15 = (raw_data15[0] >= 8) & (raw_data15[0] <= 14)
range_off18 = (raw_data18[0] >= 0) & (raw_data18[0] <= 6)
range_on18 = (raw_data18[0] >= 8) & (raw_data18[0] <= 14)
range_off25 = (raw_data25[0] >= 0) & (raw_data25[0] <= 6)
range_on25 = (raw_data25[0] >= 10) & (raw_data25[0] <= 16)
range_off30 = (raw_data30[0] >= 0) & (raw_data30[0] <= 6)
range_on30 = (raw_data30[0] >= 8) & (raw_data30[0] <= 14)
range_off40 = (raw_data40[0] >= 0) & (raw_data40[0] <= 6)
range_on40 = (raw_data40[0] >= 8) & (raw_data40[0] <= 14)

By_off00 = np.mean(raw_data00[1][range_off00]/(10**6)), st_err(raw_data00[1][range_off00]/(10**6))
By_on00 = np.mean(raw_data00[1][range_on00]/(10**6)), st_err(raw_data00[1][range_on00]/(10**6))
Bz_off00 = np.mean(raw_data00[2][range_off00]/(10**6)), st_err(raw_data00[2][range_off00]/(10**6))
Bz_on00 = np.mean(raw_data00[2][range_on00]/(10**6)), st_err(raw_data00[2][range_on00]/(10**6))
By_off03 = np.mean(raw_data03[1][range_off03]/(10**6)), st_err(raw_data03[1][range_off03]/(10**6))
By_on03 = np.mean(raw_data03[1][range_on03]/(10**6)), st_err(raw_data03[1][range_on03]/(10**6))
Bz_off03 = np.mean(raw_data03[2][range_off03]/(10**6)), st_err(raw_data03[2][range_off03]/(10**6))
Bz_on03 = np.mean(raw_data03[2][range_on03]/(10**6)), st_err(raw_data03[2][range_on03]/(10**6))
By_off05 = np.mean(raw_data05[1][range_off05]/(10**6)), st_err(raw_data05[1][range_off05]/(10**6))
By_on05 = np.mean(raw_data05[1][range_on05]/(10**6)), st_err(raw_data05[1][range_on05]/(10**6))
Bz_off05 = np.mean(raw_data05[2][range_off05]/(10**6)), st_err(raw_data05[2][range_off05]/(10**6))
Bz_on05 = np.mean(raw_data05[2][range_on05]/(10**6)), st_err(raw_data05[2][range_on05]/(10**6))
By_off08 = np.mean(raw_data08[1][range_off08]/(10**6)), st_err(raw_data08[1][range_off08]/(10**6))
By_on08 = np.mean(raw_data08[1][range_on08]/(10**6)), st_err(raw_data08[1][range_on08]/(10**6))
Bz_off08 = np.mean(raw_data08[2][range_off08]/(10**6)), st_err(raw_data08[2][range_off08]/(10**6))
Bz_on08 = np.mean(raw_data08[2][range_on08]/(10**6)), st_err(raw_data08[2][range_on08]/(10**6))
By_off09 = np.mean(raw_data09[1][range_off09]/(10**6)), st_err(raw_data09[1][range_off09]/(10**6))
By_on09 = np.mean(raw_data09[1][range_on09]/(10**6)), st_err(raw_data09[1][range_on09]/(10**6))
Bz_off09 = np.mean(raw_data09[2][range_off09]/(10**6)), st_err(raw_data09[2][range_off09]/(10**6))
Bz_on09 = np.mean(raw_data09[2][range_on09]/(10**6)), st_err(raw_data09[2][range_on09]/(10**6))
By_off12 = np.mean(raw_data12[1][range_off12]/(10**6)), st_err(raw_data12[1][range_off12]/(10**6))
By_on12 = np.mean(raw_data12[1][range_on12]/(10**6)), st_err(raw_data12[1][range_on12]/(10**6))
Bz_off12 = np.mean(raw_data12[2][range_off12]/(10**6)), st_err(raw_data12[2][range_off12]/(10**6))
Bz_on12 = np.mean(raw_data12[2][range_on12]/(10**6)), st_err(raw_data12[2][range_on12]/(10**6))
By_off15 = np.mean(raw_data15[1][range_off15]/(10**6)), st_err(raw_data15[1][range_off15]/(10**6))
By_on15 = np.mean(raw_data15[1][range_on15]/(10**6)), st_err(raw_data15[1][range_on15]/(10**6))
Bz_off15 = np.mean(raw_data15[2][range_off15]/(10**6)), st_err(raw_data15[2][range_off15]/(10**6))
Bz_on15 = np.mean(raw_data15[2][range_on15]/(10**6)), st_err(raw_data15[2][range_on15]/(10**6))
By_off18 = np.mean(raw_data18[1][range_off18]/(10**6)), st_err(raw_data18[1][range_off18]/(10**6))
By_on18 = np.mean(raw_data18[1][range_on18]/(10**6)), st_err(raw_data18[1][range_on18]/(10**6))
Bz_off18 = np.mean(raw_data18[2][range_off18]/(10**6)), st_err(raw_data18[2][range_off18]/(10**6))
Bz_on18 = np.mean(raw_data18[2][range_on18]/(10**6)), st_err(raw_data18[2][range_on18]/(10**6))
By_off25 = np.mean(raw_data25[1][range_off25]/(10**6)), st_err(raw_data25[1][range_off25]/(10**6))
By_on25 = np.mean(raw_data25[1][range_on25]/(10**6)), st_err(raw_data25[1][range_on25]/(10**6))
Bz_off25 = np.mean(raw_data25[2][range_off25]/(10**6)), st_err(raw_data25[2][range_off25]/(10**6))
Bz_on25 = np.mean(raw_data25[2][range_on25]/(10**6)), st_err(raw_data25[2][range_on25]/(10**6))
By_off30 = np.mean(raw_data30[1][range_off30]/(10**6)), st_err(raw_data30[1][range_off30]/(10**6))
By_on30 = np.mean(raw_data30[1][range_on30]/(10**6)), st_err(raw_data30[1][range_on30]/(10**6))
Bz_off30 = np.mean(raw_data30[2][range_off30]/(10**6)), st_err(raw_data30[2][range_off30]/(10**6))
Bz_on30 = np.mean(raw_data30[2][range_on30]/(10**6)), st_err(raw_data30[2][range_on30]/(10**6))
By_off40 = np.mean(raw_data40[1][range_off40]/(10**6)), st_err(raw_data40[1][range_off40]/(10**6))
By_on40 = np.mean(raw_data40[1][range_on40]/(10**6)), st_err(raw_data40[1][range_on40]/(10**6))
Bz_off40 = np.mean(raw_data40[2][range_off40]/(10**6)), st_err(raw_data40[2][range_off40]/(10**6))
Bz_on40 = np.mean(raw_data40[2][range_on40]/(10**6)), st_err(raw_data40[2][range_on40]/(10**6))

"""print(By_off00)
print(By_on00)
print(Bz_off00)
print(Bz_on00)
print("")
print(By_off03)
print(By_on03)
print(Bz_off03)
print(Bz_on03)
print("")
print(By_off05)
print(By_on05)
print(Bz_off05)
print(Bz_on05)
print("")
print(By_off08)
print(By_on08)
print(Bz_off08)
print(Bz_on08)
print("")
print(By_off09)
print(By_on09)
print(Bz_off09)
print(Bz_on09)
print("")
print(By_off12)
print(By_on12)
print(Bz_off12)
print(Bz_on12)
print("")
print(By_off15)
print(By_on15)
print(Bz_off15)
print(Bz_on15)
print("")
print(By_off18)
print(By_on18)
print(Bz_off18)
print(Bz_on18)
print("")
print(By_off25)
print(By_on25)
print(Bz_off25)
print(Bz_on25)
print("")
print(By_off30)
print(By_on30)
print(Bz_off30)
print(Bz_on30)
print("")
print(By_off40)
print(By_on40)
print(Bz_off40)
print(Bz_on40)"""

delta_By00 = By_on00[0] - By_off00[0], np.sqrt(By_on00[1]**2 + By_off00[1]**2)
delta_By03 = By_on03[0] - By_off03[0], np.sqrt(By_on03[1]**2 + By_off03[1]**2)
delta_By05 = By_on05[0] - By_off05[0], np.sqrt(By_on05[1]**2 + By_off05[1]**2)
delta_By08 = By_on08[0] - By_off08[0], np.sqrt(By_on08[1]**2 + By_off08[1]**2)
delta_By09 = By_on09[0] - By_off09[0], np.sqrt(By_on09[1]**2 + By_off09[1]**2)
delta_By12 = By_on12[0] - By_off12[0], np.sqrt(By_on12[1]**2 + By_off12[1]**2)
delta_By15 = By_on15[0] - By_off15[0], np.sqrt(By_on15[1]**2 + By_off15[1]**2)
delta_By18 = By_on18[0] - By_off18[0], np.sqrt(By_on18[1]**2 + By_off18[1]**2)
delta_By25 = By_on25[0] - By_off25[0], np.sqrt(By_on25[1]**2 + By_off25[1]**2)
delta_By30 = By_on30[0] - By_off30[0], np.sqrt(By_on30[1]**2 + By_off30[1]**2)
delta_By40 = By_on40[0] - By_off40[0], np.sqrt(By_on40[1]**2 + By_off40[1]**2)
delta_Bz00 = Bz_on00[0] - Bz_off00[0], np.sqrt(Bz_on00[1]**2 + Bz_off00[1]**2)
delta_Bz03 = Bz_on03[0] - Bz_off03[0], np.sqrt(Bz_on03[1]**2 + Bz_off03[1]**2)
delta_Bz05 = Bz_on05[0] - Bz_off05[0], np.sqrt(Bz_on05[1]**2 + Bz_off05[1]**2)
delta_Bz08 = Bz_on08[0] - Bz_off08[0], np.sqrt(Bz_on08[1]**2 + Bz_off08[1]**2)
delta_Bz09 = Bz_on09[0] - Bz_off09[0], np.sqrt(Bz_on09[1]**2 + Bz_off09[1]**2)
delta_Bz12 = Bz_on12[0] - Bz_off12[0], np.sqrt(Bz_on12[1]**2 + Bz_off12[1]**2)
delta_Bz15 = Bz_on15[0] - Bz_off15[0], np.sqrt(Bz_on15[1]**2 + Bz_off15[1]**2)
delta_Bz18 = Bz_on18[0] - Bz_off18[0], np.sqrt(Bz_on18[1]**2 + Bz_off18[1]**2)
delta_Bz25 = Bz_on25[0] - Bz_off25[0], np.sqrt(Bz_on25[1]**2 + Bz_off25[1]**2)
delta_Bz30 = Bz_on30[0] - Bz_off30[0], np.sqrt(Bz_on30[1]**2 + Bz_off30[1]**2)
delta_Bz40 = Bz_on40[0] - Bz_off40[0], np.sqrt(Bz_on40[1]**2 + Bz_off40[1]**2)

"""print(delta_By00)
print(delta_Bz00)
print(delta_By03)
print(delta_Bz03)
print(delta_By05)
print(delta_Bz05)
print(delta_By08)
print(delta_Bz08)
print(delta_By09)
print(delta_Bz09)
print(delta_By12)
print(delta_Bz12)
print(delta_By15)
print(delta_Bz15)
print(delta_By18)
print(delta_Bz18)
print(delta_By25)
print(delta_Bz25)
print(delta_By30)
print(delta_Bz30)
print(delta_By40)
print(delta_Bz40)"""

B_y = np.array([delta_By00[0], delta_By03[0], delta_By05[0], delta_By08[0], delta_By09[0], delta_By12[0], delta_By15[0], delta_By18[0], delta_By25[0], delta_By30[0], delta_By40[0]])

x = np.array([0.0, 0.3, 0.5, 0.8, 0.9, 1.2, 1.5, 1.8, 2.5, 3.0, 4.0]) / 100
d = 0.9 / 100
y = 1.2 / 100

one_over_req = y* (1/(y**2 + x**2)-1/(y**2+(x-d)**2))
partial_y = (x**2-y**2)/(x**2 + y**2)**2 - ((x-d)**2-y**2)/((x-d)**2 + y**2)**2
partial_x = -2*x*y/(x**2 + y**2)**2 + 2*(x-d)*y/((x-d)**2 + y**2)**2
partial_d = -2*(x-d)*y/((x-d)**2 + y**2)**2

err = np.sqrt((partial_d*0.001)**2 + (partial_y*0.001)**2 + (partial_x*0.001)**2)

model_opt, model_cov = opt.curve_fit(linear_model, B_y, one_over_req, sigma = err, absolute_sigma = True)
m_lin, c_lin = model_opt
dm_lin, dc_lin = np.sqrt(np.diag(model_cov))

print("m = %5.11f \u00b1 %5.11f " % (m_lin, dm_lin))
print("c = %5.8f \u00b1 %5.8f " % (c_lin, dc_lin))


plt.errorbar(one_over_req, B_y, xerr = err,fmt = "ko", label = "data points")
plt.plot(one_over_req, 1 / m_lin * one_over_req - c_lin / m_lin, label = "linear fit")
plt.xlabel("1 / equivalent radius (m^-1)")
plt.ylabel("By (T)")
plt.legend()
plt.title("        Magnetic Field (By) vs. inverse of Equivalent Radius")
plt.show()

def chisq(predicted, observed, errors):
    res = observed-predicted
    norm_res = res / errors 
    return np.sum(norm_res**2)

chisq1 = chisq(one_over_req, m_lin * B_y + c_lin, err)
reduced_chisq1 = chisq1 / 9

print("reduced chisq =", reduced_chisq1)

print("I(exp) = %5.11f \u00b1 %5.11f " % (2*np.pi / mu / m_lin, 2*np.pi / mu / m_lin * dm_lin / m_lin))
print("")

B_z = np.array([delta_Bz00[0], delta_Bz03[0], delta_Bz05[0], delta_Bz08[0], delta_Bz09[0], delta_Bz12[0], delta_Bz15[0], delta_Bz18[0], delta_Bz25[0], delta_Bz30[0], delta_Bz40[0]])

one_over_req2 = x* (1/(y**2 + x**2))-(x-d)/(y**2+(x-d)**2)

partial_y2 = (-2*y*x)/(x**2 + y**2)**2 - ((x-d)*-2*y)/((x-d)**2 + y**2)**2
partial_x2 = (y**2 - x**2)/(x**2 + y**2)**2 + (-y**2-(x-d)**2+2*(x-d)**2)/((x-d)**2 + y**2)**2
partial_d2 = (y**2+(x-d)**2-2*(x-d)**2)/((x-d)**2 + y**2)**2

err2 = np.sqrt((partial_d2*0.001)**2 + (partial_y2*0.001)**2 + (partial_x2*0.001)**2)

model_opt2, model_cov2 = opt.curve_fit(linear_model, B_z, one_over_req2, sigma = err2, absolute_sigma = True)
m_lin2, c_lin2 = model_opt2
dm_lin2, dc_lin2 = np.sqrt(np.diag(model_cov2))

print("m2 = %5.11f \u00b1 %5.11f " % (m_lin2, dm_lin2))
print("c2 = %5.8f \u00b1 %5.8f " % (c_lin2, dc_lin2))

plt.errorbar(one_over_req2, B_z, xerr = err2,fmt = "ko", label = "data points")
plt.plot(one_over_req2, 1 / m_lin2 * one_over_req2 - c_lin2 / m_lin2, label = "linear fit")
plt.xlabel("1 / equivalent radius (m^-1)")
plt.ylabel("Bz (T)")
plt.legend()
plt.title("        Magnetic Field (Bz) vs. inverse of Equivalent Radius")
plt.show()

chisq2 = chisq(one_over_req2, m_lin2 * B_z + c_lin2, err2)
reduced_chisq2 = chisq2 / 9

print("reduced chisq 2 =", reduced_chisq2)

print("I(exp) = %5.11f \u00b1 %5.11f " % (2*np.pi / mu / m_lin2,  2*np.pi / mu / m_lin2 * dm_lin2 / m_lin2))
print("")
# Out:
# m = 1191173.25849854993 ± 111043.70602975441
# c = -0.25136903 ± 0.82135925
# reduced chisq = 0.6234404782813434
# I(exp) = 4.19754218088 ± 0.39130381467
#
# m2 = 1286274.60895908740 ± 97188.23181240300
# c2 = -1.38600425 ± 0.61673928
# reduced chisq 2 = 1.841898468968651
# I(exp) = 3.88719482018 ± 0.29370834863
